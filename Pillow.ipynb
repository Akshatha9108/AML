# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from PIL import Image

# %%
image=Image.open("/home/student/Desktop/download.jpeg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=274x184 at 0x7F99805F7400>

# %%
print("Image formaat:",image.format)
# Out:
# Image formaat: JPEG

# %%
grey_image=image.convert("L")
print(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=274x184 at 0x7F99806D0A30>

# %%
grey_image
# Out:
# <PIL.Image.Image image mode=L size=274x184 at 0x7F99806D0A30>
